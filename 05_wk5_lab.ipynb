# %% [markdown]
# # Week 5 Lab: From Aggregation to Visualization & Midterm Prep
#
# <a href="https://colab.research.google.com/github/bradleyboehmke/uc-bana-4080/blob/main/labs/05_wk5_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# This lab builds directly on Week 4’s work with the `completejourney_py` dataset. We’ll take some aggregated results from last week and turn them into effective visualizations using **Pandas**, **Matplotlib**, and **Bokeh**. Then you’ll work through your own visualizations, and finally begin exploring ideas for your **midterm project**.
#
# **Agenda**
# - **Part 1 (10–15 min):** Instructor demo – from aggregation to visualization
# - **Part 2 (20–30 min):** Challenge – create visualizations for three business questions
# - **Part 3 (20–30 min):** Midterm exploration – brainstorm and investigate possible project ideas
#
# > **Sharing:** In Part 2, everyone should be prepared to share one visualization. We’ll call on a few groups.
# >
# > **Midterm Timing:** By the end of **Week 6’s lab**, you must have **approval** on your midterm business question. There are **no hard deliverables** due at the end of this lab, but you’re encouraged to discuss ideas today.

# %% [markdown]
# ## Setup (run once)

# %%
# %pip install matplotlib
# %pip install bokeh

# Core
import pandas as pd
import numpy as np

# Viz
import matplotlib.pyplot as plt
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool

# Data
from completejourney_py import get_data

# Display Bokeh inline (Jupyter/Colab)
output_notebook()

# Load completejourney data
cj = get_data()
transactions = cj['transactions']
products = cj['products']
demographics = cj['demographics']

# Optional: set a clean default style for Matplotlib
plt.rcParams["figure.figsize"] = (8, 4.5)
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.titlesize"] = 12
plt.rcParams["axes.labelsize"] = 10
# Out:
# Requirement already satisfied: matplotlib in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\tyler\appdata\roaming\python\python312\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tyler\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\tyler\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   WARNING: The script bokeh.exe is installed in 'c:\Users\tyler\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting bokeh
#   Obtaining dependency information for bokeh from https://files.pythonhosted.org/packages/f6/a8/877f306720bc114c612579c5af36bcb359026b83d051226945499b306b1a/bokeh-3.8.2-py3-none-any.whl.metadata
#   Downloading bokeh-3.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (1.3.3)
# Collecting narwhals>=1.13 (from bokeh)
#   Obtaining dependency information for narwhals>=1.13 from https://files.pythonhosted.org/packages/03/cc/7cb74758e6df95e0c4e1253f203b6dd7f348bf2f29cf89e9210a2416d535/narwhals-2.16.0-py3-none-any.whl.metadata
#   Downloading narwhals-2.16.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.16 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (2.4.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\tyler\appdata\roaming\python\python312\site-packages (from bokeh) (26.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (3.0.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (12.1.1)
# Collecting PyYAML>=3.10 (from bokeh)
#   Obtaining dependency information for PyYAML>=3.10 from https://files.pythonhosted.org/packages/86/bf/899e81e4cce32febab4fb42bb97dcdf66bc135272882d1987881a4b519e9/pyyaml-6.0.3-cp312-cp312-win_amd64.whl.metadata
#   Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: tornado>=6.2 in c:\users\tyler\appdata\roaming\python\python312\site-packages (from bokeh) (6.5.4)
# Collecting xyzservices>=2021.09.1 (from bokeh)
#   Obtaining dependency information for xyzservices>=2021.09.1 from https://files.pythonhosted.org/packages/ef/5c/2c189d18d495dd0fa3f27ccc60762bbc787eed95b9b0147266e72bb76585/xyzservices-2025.11.0-py3-none-any.whl.metadata
#   Downloading xyzservices-2025.11.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from Jinja2>=2.9->bokeh) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tyler\appdata\roaming\python\python312\site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\tyler\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->bokeh) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\tyler\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.17.0)
# Downloading bokeh-3.8.2-py3-none-any.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.2 MB 2.0 MB/s eta 0:00:04
#    ---------------------------------------- 0.1/7.2 MB 1.3 MB/s eta 0:00:06
#     --------------------------------------- 0.2/7.2 MB 1.5 MB/s eta 0:00:05
#    -- ------------------------------------- 0.4/7.2 MB 2.4 MB/s eta 0:00:03
#    --- ------------------------------------ 0.6/7.2 MB 2.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.7/7.2 MB 3.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.8/7.2 MB 2.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/7.2 MB 2.9 MB/s eta 0:00:03
#    ------ --------------------------------- 1.2/7.2 MB 3.2 MB/s eta 0:00:02
#    -------- ------------------------------- 1.5/7.2 MB 3.5 MB/s eta 0:00:02
#    --------- ------------------------------ 1.7/7.2 MB 3.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.0/7.2 MB 3.9 MB/s eta 0:00:02
#    ------------ --------------------------- 2.3/7.2 MB 4.1 MB/s eta 0:00:02
#    --------------- ------------------------ 2.7/7.2 MB 4.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.1/7.2 MB 4.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.2/7.2 MB 4.6 MB/s eta 0:00:01
#    ------------------ --------------------- 3.3/7.2 MB 4.5 MB/s eta 0:00:01
#    --------------------- ------------------ 3.8/7.2 MB 4.8 MB/s eta 0:00:01
#    ------------------------ --------------- 4.4/7.2 MB 5.2 MB/s eta 0:00:01
#    -------------------------- ------------- 4.7/7.2 MB 5.4 MB/s eta 0:00:01
#    --------------------------- ------------ 5.0/7.2 MB 5.4 MB/s eta 0:00:01
#    ------------------------------ --------- 5.5/7.2 MB 5.7 MB/s eta 0:00:01
#    ------------------------------ --------- 5.6/7.2 MB 5.4 MB/s eta 0:00:01
#    -------------------------------- ------- 5.9/7.2 MB 5.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.3/7.2 MB 5.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.4/7.2 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------- -- 6.8/7.2 MB 5.6 MB/s eta 0:00:01
#    -------------------------------------- - 6.9/7.2 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  7.2/7.2 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 5.4 MB/s eta 0:00:00
# Downloading narwhals-2.16.0-py3-none-any.whl (443 kB)
#    ---------------------------------------- 0.0/444.0 kB ? eta -:--:--
#    ---------------------------------------- 444.0/444.0 kB 9.2 MB/s eta 0:00:00
# Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl (154 kB)
#    ---------------------------------------- 0.0/154.0 kB ? eta -:--:--
#    ---------------------------------------- 154.0/154.0 kB 4.5 MB/s eta 0:00:00
# Downloading xyzservices-2025.11.0-py3-none-any.whl (93 kB)
#    ---------------------------------------- 0.0/93.9 kB ? eta -:--:--
#    ---------------------------------------- 93.9/93.9 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: xyzservices, PyYAML, narwhals, bokeh
# Successfully installed PyYAML-6.0.3 bokeh-3.8.2 narwhals-2.16.0 xyzservices-2025.11.0
# Note: you may need to restart the kernel to use updated packages.
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d99ab096-682a-4c9b-ada5-e0713d1a2364">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# 📄 **Data dictionary:** https://bradleyboehmke.github.io/completejourney/articles/completejourney.html

# %% [markdown]
# ## Part 1 — Demo: Visualizing Week 4 Aggregations (Instructor-led)
#
# We’ll walk through three examples that show how to move from **aggregated data** to **clear visualizations**.

# %% [markdown]
# ### 1A) Total **sales by product category** → Bar chart (Pandas)
#
# **Idea:** Join transactions ↔ products to get `product_category`, aggregate sales per category, then plot the top categories.
#
# **Why Pandas here?** It’s perfect for fast exploratory charts tied directly to a Series/DataFrame.

# %%
# Ensure data is loaded
if "transactions" not in globals() or "products" not in globals():
    try:
        get_data
    except NameError:
        from completejourney_py import get_data
    cj = get_data()
    transactions = cj["transactions"]
    products = cj["products"]

# Join transactions to products to bring in product_category
tx_prod = transactions.merge(
    products[["product_id", "product_category"]],
    on="product_id",
    how="left"
)

# Aggregate: total sales by product_category
sales_by_cat = (
    tx_prod
    .groupby("product_category", dropna=False)["sales_value"]
    .sum()
    .sort_values(ascending=False)
    .head(15)  # top 15 for readability
)

# Quick bar plot with Pandas
ax = sales_by_cat.plot(kind="bar")
ax.set_title("Top 15 Categories by Total Sales")
ax.set_xlabel("Product Category")
ax.set_ylabel("Total Sales ($)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1B) **Monthly revenue trend** → Line chart (Matplotlib)
#
# **Idea:** Convert timestamps → monthly periods and sum sales per month; plot with Matplotlib for finer control.
#
# **Why Matplotlib here?** You get fine-grained control over styling, markers, and layout.

# %%
# Ensure transaction timestamp is datetime
# Aggregate to monthly sales (Month Start frequency)
monthly_sales = (
    transactions
    .set_index("transaction_timestamp")
    .resample("MS")["sales_value"]
    .sum()
    .rename("monthly_sales")
)

# set plot style
plt.style.use('fivethirtyeight')

# Matplotlib line chart with markers
fig, ax = plt.subplots()
ax.plot(monthly_sales.index, monthly_sales.values, linestyle="--", linewidth=1, marker="o")
ax.set_title("Monthly Revenue Trend")
ax.set_xlabel("Month")
ax.set_ylabel("Sales ($)")
ax.tick_params(axis="x", rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1C) **Top 10 products by sales** → Interactive horizontal bar (Bokeh + hover)
#
# **Idea:** Aggregate total sales by product, grab descriptions, and build an interactive bar chart with hover labels.
#
# **Why Bokeh here?** Interactivity (hover, zoom, pan) and browser-based rendering—great for exploratory storytelling.  There's a lot more customization that could be done here -- see here for examples: https://docs.bokeh.org/en/latest/docs/user_guide/basic/bars.html

# %%
if "sales_by_product" not in globals():
	sales_by_product = (
		transactions
		.merge(products, on="product_id", how="left")
		.groupby("product_type")["sales_value"]
		.sum()
		.sort_values(ascending=False)
		.head(10)
		.reset_index()
	)

sales_by_product.head()
# Out:
#                      product_type  sales_value
# 0           GASOLINE-REG UNLEADED    384044.07
# 1           FLUID MILK WHITE ONLY     91834.49
# 2  SOFT DRINKS 12/18&15PK CAN CAR     89656.71
# 3             BEERALEMALT LIQUORS     82691.86
# 4                      CIGARETTES     54349.68

# %%
# Aggregate: total sales by product
sales_by_product = (
    transactions
    .merge(products, on="product_id", how="left")
    .groupby("product_type")["sales_value"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()

)

# Prepare categorical y-axis and values
factors = list(sales_by_product["product_type"].fillna("Unknown"))
values = list(sales_by_product["sales_value"])

# Bokeh figure (output_notebook() already called in Setup)
p = figure(
    y_range=factors,
    height=360,
    title="Top 10 Products by Sales (Interactive)",
    toolbar_location=None,
    tools=""

)

# Horizontal bars
p.hbar(y=factors, right=values, height=0.6)

# Add hover to show product name and formatted sales
hover = HoverTool(tooltips=[("Product", "@y"), ("Sales", "@right{$0,0.00}")])
p.add_tools(hover)

# other customizations
p.xaxis.axis_label = "Sales ($)"
p.yaxis.axis_label = "Product"
p.x_range.start = 0

# Format x-axis ticks to avoid scientific notation
from bokeh.models import NumeralTickFormatter
p.xaxis.formatter = NumeralTickFormatter(format="0,0")

show(p)
# Out:
#   <div id="ff7aec5e-3aaa-447f-84e4-d5f729565794" data-root-id="p1043" style="display: contents;"></div>

# %% [markdown]
# ## Part 2 — Challenge: Answer Business Questions with Visualizations (20–30 min)
#
# Work in small groups to answer **1 or more** of these three **business questions** using the `completejourney_py` data.
#
# For each question:
# 1. Read the business question.
# 2. Review the example **analytic approach** — this breaks the business problem into tangible steps you’ve learned so far.
# 3. Use the provided analysis code to **generate the aggregated results** (code below purposely **does not** include plotting).
# 4. **Your task:** Create a clear visualization of those results using **Pandas, Matplotlib, or Bokeh**.
#
# 💡 **Flexibility Note:** You are encouraged to **modify the analysis** if you have a different idea for exploring or visualizing the results. For example:
# - **Question 1:** Instead of just comparing households with vs. without kids, you could break down **snack sales by the number of children** in the household.
# - **Question 2:** You could group similar product categories together to simplify the results.
# - **Question 3:** You could compare soft drink trends across weekdays or highlight seasonal peaks.
#
# The goal is to answer the business question in a way that makes the insights clear.

# %% [markdown]
# ### Business Question 1
# **Do households with children purchase more snack products than households without children?**
#
# **Analytic Approach**
# - Join transactions ↔ products to get required product information.
# - Filter transactions to include only products that fall under the `SNACKS` type.
# - Join transactions to the `demographics` dataset to identify households with children.
# - Create a binary indicator for presence of children.
# - Aggregate total snack sales for households **with** vs. **without** children.

# %%
from bokeh.models import Range1d, ColumnDataSource
from bokeh.palettes import Category10

# Join products to get category
tx_prod = transactions.merge(products, on="product_id", how="left")

# Filter to snacks only
snack_sales = tx_prod[tx_prod["product_type"].str.contains("Snacks", case=False, na=False)]

# Join demographics to identify households with children
snack_demo = snack_sales.merge(demographics, on="household_id", how="left")

# Create a binary indicator for presence of children
snack_demo["has_kids"] = snack_demo["kids_count"] != "0"

# Aggregate total sales by presence of children
sales_by_children = (
    snack_demo
    .groupby("has_kids", as_index=False)
    .agg(total_sales=("sales_value", "sum"))
)

labels = ["No Kids", "Has Kids"]
sales_by_children["label"] = sales_by_children["has_kids"].map({False: "No Kids", True: "Has Kids"})
sales_by_children = sales_by_children.set_index("label").reindex(labels).reset_index()

colors = [Category10[3][0], Category10[3][1]]
source = ColumnDataSource(data={
    "label": labels,
    "total_sales": list(sales_by_children["total_sales"]),
    "color": colors,
})

p = figure(
    x_range=labels,
    y_range=Range1d(0, float(sales_by_children["total_sales"].max()) * 1.1),
    height=360,
    title="Total Snack Sales for Households with vs without Children",
    toolbar_location=None,
    tools=""
 )
p.vbar(x="label", top="total_sales", width=0.6, color="color", source=source)
hover = HoverTool(tooltips=[("Has Kids", "@label"), ("Total Sales", "@total_sales{$0,0.00}")])
p.add_tools(hover)
p.xaxis.axis_label = "Household Type"
p.yaxis.axis_label = "Total Sales ($)"
p.yaxis.formatter = NumeralTickFormatter(format="0,0")
show(p)


sales_by_children.head()
# Out:
#   <div id="ba3cf4c1-069f-42e5-adc6-1ce10bc0cb3d" data-root-id="p1366" style="display: contents;"></div>
#       label  has_kids  total_sales
# 0   No Kids     False     15362.67
# 1  Has Kids      True     39544.67

# %% [markdown]
# ### Business Question 2
# **Which product categories generated the most revenue during December 2017?**
#
# **Analytic Approach**
# - Filter transactions for the month of **December 2017**.
# - Join transactions to products to get `product_category`.
# - Aggregate total sales by category.
# - Sort results to find the top categories.

# %%
# Filter to December 2017
december_tx = transactions[
    (transactions["transaction_timestamp"].dt.year == 2017) &
    (transactions["transaction_timestamp"].dt.month == 12)
]

# Join products for category
december_tx_prod = december_tx.merge(products, on="product_id", how="left")

# Aggregate sales by category
sales_by_category_dec = (
    december_tx_prod
    .groupby("product_category", as_index=False)
    .agg(total_sales=("sales_value", "sum"))
    .sort_values("total_sales", ascending=False)
)

sales_by_category_dec.head()
# Out:
#         product_category  total_sales
# 75     COUPON/MISC ITEMS     31878.31
# 255          SOFT DRINKS     14904.34
# 23                  BEEF     14417.55
# 120  FLUID MILK PRODUCTS     10984.17
# 49                CHEESE     10581.36

# %%
if "plt" not in globals():
    import matplotlib.pyplot as plt

if "transactions" not in globals() or "products" not in globals():
    try:
        get_data
    except NameError:
        from completejourney_py import get_data
    cj = get_data()
    transactions = cj["transactions"]
    products = cj["products"]

if "sales_by_category_dec" not in globals():
    # Filter to December 2017
    december_tx = transactions[
        (transactions["transaction_timestamp"].dt.year == 2017) &
        (transactions["transaction_timestamp"].dt.month == 12)
    ]

    # Join products for category
    december_tx_prod = december_tx.merge(products, on="product_id", how="left")

    # Aggregate sales by category
    sales_by_category_dec = (
        december_tx_prod
        .groupby("product_category", as_index=False)
        .agg(total_sales=("sales_value", "sum"))
        .sort_values("total_sales", ascending=False)
    )

ax = sales_by_category_dec.head(10).plot(
    x="product_category",
    y="total_sales",
    kind="barh"
)
ax.set_title("Top 10 Categories by Sales (Dec 2017)")
ax.set_xlabel("Total Sales ($)")
ax.set_ylabel("Product Category")

plt.tight_layout()
plt.show()

# %%
# Plot top categories for December 2017 (interactive)
if "sales_by_category_dec" not in globals():
    # Filter to December 2017
    december_tx = transactions[
        (transactions["transaction_timestamp"].dt.year == 2017) &
        (transactions["transaction_timestamp"].dt.month == 12)
    ]

    # Join products for category
    december_tx_prod = december_tx.merge(products, on="product_id", how="left")

    # Aggregate sales by category
    sales_by_category_dec = (
        december_tx_prod
        .groupby("product_category", as_index=False)
        .agg(total_sales=("sales_value", "sum"))
        .sort_values("total_sales", ascending=False)
    )

top_dec = sales_by_category_dec.head(10).copy()
categories = list(top_dec["product_category"].fillna("Unknown"))
values = list(top_dec["total_sales"])
total = sum(values)
share = [v / total if total else 0 for v in values]

from bokeh.palettes import Category10
from bokeh.models import ColumnDataSource
colors = Category10[10]

source = ColumnDataSource(data={
    "category": categories,
    "total_sales": values,
    "share": share,
    "color": colors,
})

p = figure(
    y_range=categories,
    height=360,
    title="Top 10 Categories by Sales (Dec 2017)",
    toolbar_location=None,
    tools=""
 )
p.hbar(y="category", right="total_sales", height=0.6, color="color", source=source)

hover = HoverTool(tooltips=[
    ("Category", "@category"),
    ("Sales", "@total_sales{$0,0}"),
    ("Share", "@share{0.0%}")
])
p.add_tools(hover)

p.xaxis.axis_label = "Total Sales ($)"
p.yaxis.axis_label = "Product Category"
p.xaxis.formatter = NumeralTickFormatter(format="0,0")
p.x_range.start = 0

show(p)
# Out:
#   <div id="b693f317-c864-481d-8e21-28c58cad7552" data-root-id="p1326" style="display: contents;"></div>

# %% [markdown]
# ### Business Question 3
# **How has the quantity of soft drink purchases changed over time?**
#
# **Analytic Approach**
#
# - Join transactions to products to get product information.
# - Filter transactions for products in the `SOFT DRINKS` category.
# - Aggregate quantity sold by month end (`"ME"`).
# - Look for upward or downward trends.

# %%
# Join products for category
tx_prod = transactions.merge(products[["product_id", "product_category"]],
                             on="product_id", how="left")

# Filter to soft drinks
soft_drinks = tx_prod[tx_prod["product_category"].str.contains("Soft drinks", case=False, na=False)].copy()

# Aggregate quantity by month
soft_drinks_monthly = (
    soft_drinks
    .set_index("transaction_timestamp")
    .resample("ME")["quantity"]
    .sum()
    .reset_index()
)

soft_drinks_monthly.head()

# %%
# Plot soft drink quantity over time
if "soft_drinks_monthly" not in globals():
    tx_prod = transactions.merge(products[["product_id", "product_category"]],
                                 on="product_id", how="left")
    soft_drinks = tx_prod[tx_prod["product_category"].str.contains("Soft drinks", case=False, na=False)].copy()
    soft_drinks_monthly = (
        soft_drinks
        .set_index("transaction_timestamp")
        .resample("ME")["quantity"]
        .sum()
        .reset_index()
    )

from bokeh.models import ColumnDataSource

# Prepare data for Bokeh
source = ColumnDataSource(data={
    "date": soft_drinks_monthly["transaction_timestamp"],
    "quantity": soft_drinks_monthly["quantity"]
})

p = figure(
    height=360,
    title="Soft Drink Quantity Over Time",
    toolbar_location=None,
    tools="",
    x_axis_type='datetime'
)

p.line(x="date", y="quantity", line_width=2, color="#1f77b4", source=source)
p.circle(x="date", y="quantity", size=6, color="#1f77b4", source=source)

hover = HoverTool(tooltips=[
    ("Month", "@date{%Y-%m}"),
    ("Quantity Sold", "@quantity{0,0}")
], formatters={"@date": "datetime"})
p.add_tools(hover)

p.xaxis.axis_label = "Month"
p.yaxis.axis_label = "Quantity Sold"
p.yaxis.formatter = NumeralTickFormatter(format="0,0")

show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 22
#      16 # Prepare data for Bokeh
#      17 source = ColumnDataSource(data={
#      18     "date": soft_drinks_monthly["transaction_timestamp"],
#      19     "quantity": soft_drinks_monthly["quantity"]
#      20 })
# ---> 22 p = figure(
#      23     height=360,
#      24     title="Soft Drink Quantity Over Time",
#      25     toolbar_location=None,
#      26     tools="",
#      27     x_axis_type='datetime'
#      28 )
#      30 p.line(x="date", y="quantity", line_width=2, color="#1f77b4", source=source)
#      31 p.circle(x="date", y="quantity", size=6, color="#1f77b4", source=source)
#
# NameError: name 'figure' is not defined

# %% [markdown]
# ## Part 3 — Midterm Project Data Exploration (20–30 min)
#
# ### Scenario
# You are a data scientist for **Regork**, a national grocery chain. Your manager has tasked you with identifying a potential growth area for the company to increase revenue and profits. You’ll present your findings and recommendations to the CEO.
#
# ### Your Task Today
# - Explore the data to identify **possible business questions**.
# - Begin drafting ideas for your **midterm report**.
# - Think about both **business relevance** and **data feasibility**.
# - Use visualizations to uncover interesting trends or anomalies.
#
# **Example directions**
# - High-value demographic–product combinations (do certain products sell better to certain age groups?)
# - Coupon redemption rates by demographic segment (are some segments more likely to use coupons?)
# - Underserved demographic segments (are there customer segments that shop infrequently?)
# - Positive/negative trends over time (are sales for certain products increasing or decreasing?)
# - Product pairings that occur together frequently (do beer and diapers go together?)
# - Seasonal or holiday-related spikes (do chips and salsa spike around the Super Bowl?)
# - Marketing campaign or coupon effectiveness (did a recent campaign increase sales?)
#
# **Midterm Timeline**
# - By the end of **Week 6’s lab**: You must have **approval** on your business question.
# - This week: No hard deliverables, but you’re encouraged to discuss your ideas.
