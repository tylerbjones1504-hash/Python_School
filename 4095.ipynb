# %%
erDiagram
    DEPARTMENT ||--|{ PROFESSOR : "employs"
    DEPARTMENT |o--|| PROFESSOR : "is chaired by"
    PROFESSOR ||--o{ PROJECT : "manages (PI)"
    PROFESSOR }o--|{ PROJECT : "works on"

    DEPARTMENT {
        int Dept_Num PK
        string Name
        string Main_Office
    }

    PROFESSOR {
        string SSN PK
        string Name
        int Age
        string Rank
        string Research_Specialty
    }

    PROJECT {
        int Project_Num PK
        string Sponsor_Name
        float Budget
    }
# Out:
#   Cell In[1], line 2
#     DEPARTMENT ||--|{ PROFESSOR : "employs"
#     ^
# IndentationError: unexpected indent
